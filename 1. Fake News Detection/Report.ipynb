# %% [markdown]
# # Fake news Detection

# %% [markdown]
# Author: Saurav Menon M

# %% [markdown]
# Date: 30 November 2020

# %% [markdown]
# ## 1. Introduction

# %% [markdown]
# A sort of sensationalist reporting, counterfeit news typifies bits of information that might be deceptions and is commonly spread through web-based media and other online media. This is regularly done to further or force certain thoughts and is frequently accomplished with political plans. Such news items may contain bogus or potentially overstated cases, and may wind up being viralized by calculations, and clients may wind up in a channel bubble.

# %% [markdown]
# ## 2. Objective

# %% [markdown]
# This task of recognizing counterfeit news manages phony and genuine news. Utilizing sklearn, we fabricate a TfidfVectorizer on our dataset. At that point, we introduce a PassiveAggressive Classifier and fit the model. Eventually, the precision score and the confusion matrix reveal to us how well our model fares.

# %% [markdown]
# ## 3. Data Description

# %% [markdown]
# The dataset we’ll use for this python project- we’ll call it NEWS.csv. This dataset has a shape of 100×4. The first column identifies the news, the second and third are the title and text, and the fourth column has labels denoting whether the news is REAL or FAKE.

# %% [markdown]
# ## 4. Methodology

# %% [markdown]
# We will be creating our model with the help of Python so we start off by importing all the required packages.
#
# Package breakdown:
#
# 1. Pandas    : To collect and manipulate data in JSON and HTMl and then data analysis
# 2. NumPy     : To manipulate data in multi-dimensional array and matrix data structures
# 3. Itertools : To work on iterators to produce complex iterators
# 4. sklearn   : To import the machine learning model that we are using

# %% [markdown]
# ### 4.1 Data Collection & Preprocessing

# %% [markdown]
# In this stage, we begin with collecting the required data from the csv file.
#
# To read the data into a DataFrame, and get the shape of the data and the first 5 records, we use the following code snippet:
#
# ![image.png](attachment:image.png)
#
# And to get the labels from the DataFrame.
#
# ![image-2.png](attachment:image-2.png)

# %% [markdown]
# ### 4.2 Train-Test Split

# %% [markdown]
# In this stage we will be dividing the dataset into two parts training set and test set.
#
# To split the dataset into training and testing sets, we use:
#
# ![image.png](attachment:image.png)

# %% [markdown]
# ### 4.3 Feature Engineering -  TfidfVectorizer

# %% [markdown]
# Stop words are the most common words in a language that are to be filtered out before processing the natural language data. And a TfidfVectorizer turns a collection of raw documents into a matrix of TF-IDF features.
#
# Now, fit and transform the vectorizer on the train set, and transform the vectorizer on the test set.
#
# ![image.png](attachment:image.png)

# %% [markdown]
# ### 4.4 Model Building - PassiveAggressiveClassifier

# %% [markdown]
# We’ll initialize a PassiveAggressiveClassifier. Then, we’ll predict on the test set from the TfidfVectorizer and calculate the accuracy with accuracy_score() from sklearn.metrics.
#
# ![image-2.png](attachment:image-2.png)

# %% [markdown]
# ### 4.5 Examining Results - Confusion Matrix

# %% [markdown]
# Finally, let’s print out a confusion matrix to gain insight into the number of false and true negatives and positives.
#
# ![image.png](attachment:image.png)

# %% [markdown]
# ## 5. Results

# %% [markdown]
# In this project, we performed an attempt to verify the news articles credibility depending on their characteristics. At this aim, we implemented an algorithm combining several classiﬁcation methods with text models. It performed well, and the accuracy results were relatively satisfying.

# %% [markdown]
# ## 6. Conclusion

# %% [markdown]
# The problems of fake news and disinformation play animportant role on nowadays life. This is because the advanced level of technology and communication methods we have enabled information spreading among people without any veriﬁcation. This is a reason why researchers started searching for solutions to stop fake news and disinformation from spreading easily.

# %% [markdown]
# ## 7. References

# %% [markdown]
# 1. A. Singhal, “Modern information retrieval: a brief overview,” BULLETINOF THE IEEE COMPUTER SOCIETY TECHNICAL COMMITTEE ONDATA ENGINEERING, vol. 24, p. 2001, 2001.
# 2. R. J. Sethi, “Crowdsourcing the veriﬁcation of fake news and alternativefacts,” in Proceedings of the 28th ACM Conference on Hypertext andSocial Media, HT ’17, (New        York, NY, USA), pp. 315–316, ACM, 2017.
# 3. P. Bourgonje, J. M. Schneider, and G. Rehm, “From clickbait to fake newsdetection: An approach based on detecting the stance of headlines to arti-cles,” in Proceedings      of Natural Language Processing meets Journalism(O. Popescu and C. Strapparava, eds.), Association for ComputationalLinguistics, 2017.
